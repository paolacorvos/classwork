# %% [markdown]
# ## Week 2 Homework

# %%
name = "Paola"
age = 20
grade = 98.0
is_student = True
favorite_color = "Blue"

# %%
name = str("Paola")
age = int(20)
grade = float(98)
is_student = bool(True)
favorite_color = str("Blue")

# %%
print(name.upper())
# Out:
# PAOLA

# %%
print(age+grade) # date type of result is a float
# Out:
# 118.0

# %%
person = {"name":"Paola", "age":"20", "grade":"3", "is_student":"True","favorite_color":"Blue"}
print(person)
# Out:
# {'name': 'Paola', 'age': '20', 'grade': '3', 'is_student': 'True', 'favorite_color': 'Blue'}

# %%
print(f"My name is {name}. I am {age} years old. My favorite color is {favorite_color}. I will get a {grade} in this class.")
# Out:
# My name is Paola. I am 20 years old. My favorite color is Blue. I will get a 98.0 in this class.
