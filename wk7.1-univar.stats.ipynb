# %%
import pandas as pd

url = "https://raw.githubusercontent.com/nkmwicz/data-for-students/refs/heads/main/soccer-players.csv"

df = pd.read_csv(url)
df.head()
# Out:
#    player_id first_name     last_name                name  last_season  \
# 0         10   Miroslav         Klose      Miroslav Klose         2015
# 1         26      Roman  Weidenfeller  Roman Weidenfeller         2017
# 2         65    Dimitar      Berbatov    Dimitar Berbatov         2015
# 3         77        NaN         Lúcio               Lúcio         2012
# 4         80        Tom        Starke          Tom Starke         2017
#
#    current_club_id         player_code    country_of_birth city_of_birth  \
# 0              398      miroslav-klose              Poland         Opole
# 1               16  roman-weidenfeller             Germany          Diez
# 2             1091    dimitar-berbatov            Bulgaria   Blagoevgrad
# 3              506               lucio              Brazil      Brasília
# 4               27          tom-starke  East Germany (GDR)       Freital
#
#   country_of_citizenship  ...   foot height_in_cm contract_expiration_date  \
# ...

# %%
def convert_height(cm):
    """
    Convert cm to feet
    
    Args:
        cm (int): the Num of cm
    Returns:
        feet (float): num of feet.
    """
    return (cm * 0.393701) / 12

# %%
df["height_in_ft"] = df["height_in_cm"].apply(convert_height)
df["height_in_ft"]
# Out:
# 0        6.036749
# 1        6.233599
# 2             NaN
# 3             NaN
# 4        6.364833
#            ...
# 32398    5.839898
# 32399    5.905515
# 32400    5.380580
# 32401         NaN
# 32402         NaN
# Name: height_in_ft, Length: 32403, dtype: float64

# %%
df.describe()
# Out:
#           player_id   last_season  current_club_id  height_in_cm  \
# count  3.240300e+04  32403.000000     32403.000000  30059.000000
# mean   3.445789e+05   2019.337777      4809.252045    182.291161
# std    2.806831e+05      3.965914     11601.982978      6.971224
# min    1.000000e+01   2012.000000         3.000000     17.000000
# 25%    1.066980e+05   2016.000000       403.000000    178.000000
# 50%    2.824210e+05   2020.000000      1071.000000    183.000000
# 75%    5.242085e+05   2023.000000      3060.000000    187.000000
# max    1.309800e+06   2024.000000    110302.000000    207.000000
#
#        market_value_in_eur  highest_market_value_in_eur  height_in_ft
# count         3.086900e+04                 3.086900e+04  30059.000000
# mean          1.611350e+06                 3.675045e+06      5.980684
# std           6.362017e+06                 9.653897e+06      0.228715
# min           1.000000e+04                 1.000000e+04      0.557743
# ...

# %%
df["height_in_cm"].std()
# Out:
# 6.971224376399549

# %%
df["height_in_ft"].var()
df["height_in_ft"].std()
# Out:
# 0.22871483401772097

# %%
df["height_in_ft"].mean()
# Out:
# np.float64(5.980684355462036)

# %%
# df["height_in_cm"] / df["height_in_ft"] 12

# %%
df["height_in_cm"].median()
# Out:
# 183.0

# %%
df["height_in_cm"].mode(0)[0]
# Out:
# np.float64(nan)

# %%
df["height_in_cm"].quantile(.33)
# Out:
# np.float64(179.0)

# %%
df["height_in_cm"].min()
# Out:
# 17.0

# %%
df["height_in_cm"].max()
# Out:
# 207.0

# %%
range = df["height_in_cm"].max() - df["height_in_cm"].min()
range
# Out:
# 190.0

# %%
df["height_in_cm"].skew()
# Out:
# np.float64(-1.7751475048518246)

# %%
from scipy import stats

sk = stats.skew(df["height_in_cm"], nan_policy = "omit")
sk
# Out:
# np.float64(-1.7750589204621978)

# %%
df["height_in_cm"].kurt()
# Out:
# np.float64(40.3723954752419)

# %%
stats.kurtosis(df["height_in_cm"].dropna())
# Out:
# np.float64(40.36548066183285)

# %%
def eda(df: pd.DataFrame) -> None:
    """
    Evaluate basic statistics on a DataFrame
    
    Args:
        df (Pandas.DataFrame): DataFrame to evaluate
    Returns:
        None
    """
    print(f"{'='*5}DF Shape: {df.shape}{'='*5}")
    num_cols = []
    cat_cols = []
    for col in df.columns:
        if pd.api.types.is_numeric_dtype(df[col]):
            num_cols.append(col) # -> "height_in_cm"
        else: 
            cat_cols.append(col)
   
    print(f"{'*'*3}NUMERIC COLUMNS{'*'*3}")
    for col in num_cols:
        n_min = df[col].min()
        n_max = df[col].max()
        num_na = df[col].isna().sum()
        print(col)
        print(f"\tNum NA: {num_na}")
        print(f"\t% NA: {(num_na / len(df)) * 100}%")
        print(f"\tMin: {n_min}")
        print(f"\tMax: {n_max}")
        print(f"\tRange: {n_max - n_min}")
        print(f"25%: {df[col].quantile(0.25)}")
        print(f"75%: {df[col].quantile(0.75)}")
        print(f"St. Dev.: {df[col].std()}")
        print(f"\tNum unique: {df[col].nunique()}")
    print("\n")
    print(f"{'*'*3} CATEGORICAL COLS{'*'*3}")
    for col in cat_cols:
        d = df[col]
        num_null = d.isna().sum()
        print(f"{col}")
        print(f"\tNum NA: {num_null}")
        print(f"\t% NA: {(num_null / len(df)) * 100}%")
        print(f"\tNum Uniques: {d.nunique()}")
        if d.nunique() < 7:
            print(f"Unique Vals: {d.unique()}")

# %%
eda(df)
# Out:
# =====DF Shape: (32403, 24)=====
# ***NUMERIC COLUMNS***
# player_id
# 	Num NA: 0
# 	% NA: 0.0%
# 	Min: 10
# 	Max: 1309800
# 	Range: 1309790
# 25%: 106698.0
# 75%: 524208.5
# St. Dev.: 280683.13989913743
# 	Num unique: 32403
# last_season
# 	Num NA: 0
# 	% NA: 0.0%
# 	Min: 2012
# 	Max: 2024
# 	Range: 12
# 25%: 2016.0
# 75%: 2023.0
# St. Dev.: 3.965914065614276
# 	Num unique: 13
# current_club_id
# 	Num NA: 0
# 	% NA: 0.0%
# 	Min: 3
# 	Max: 110302
# 	Range: 110299
# 25%: 403.0
# 75%: 3060.0
# St. Dev.: 11601.982977954987
# 	Num unique: 437
# height_in_cm
# 	Num NA: 2344
# 	% NA: 7.233898095855322%
# 	Min: 17.0
# 	Max: 207.0
# 	Range: 190.0
# 25%: 178.0
# 75%: 187.0
# St. Dev.: 6.971224376399549
# 	Num unique: 52
# market_value_in_eur
# 	Num NA: 1534
# 	% NA: 4.734129555905318%
# 	Min: 10000.0
# 	Max: 200000000.0
# 	Range: 199990000.0
# 25%: 100000.0
# 75%: 700000.0
# St. Dev.: 6362017.247132119
# 	Num unique: 129
# highest_market_value_in_eur
# 	Num NA: 1534
# ...
